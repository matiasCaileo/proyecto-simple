# %%
from kedro.framework.session import KedroSession
from kedro.framework.startup import bootstrap_project
from pathlib import Path

bootstrap_project(Path.cwd().parent)
session = KedroSession.create()
catalog = session.load_context().catalog
# Out:
# [03/20/26 11:55:04] INFO     Using                                                                  ]8;id=140982;file://C:\Users\pc\mi-proyecto-kedro\.venv\Lib\site-packages\kedro\framework\project\__init__.py\__init__.py]8;;\:]8;id=858479;file://C:\Users\pc\mi-proyecto-kedro\.venv\Lib\site-packages\kedro\framework\project\__init__.py#269\269]8;;\
#                              'C:\Users\pc\mi-proyecto-kedro\.venv\Lib\site-packages\kedro\framework
#                              \project\rich_logging.yml' as logging configuration.
# [03/20/26 11:55:51] INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=115159;file://C:\Users\pc\mi-proyecto-kedro\.venv\Lib\site-packages\kedro_telemetry\plugin.py\plugin.py]8;;\:]8;id=137697;file://C:\Users\pc\mi-proyecto-kedro\.venv\Lib\site-packages\kedro_telemetry\plugin.py#242\242]8;;\
#                              the product. No personal data or IP addresses are stored on our side. To
#                              opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK` environment
#                              variables, or create a `.telemetry` file in the current working
#                              directory with the contents `consent: false`. To hide this message,
#                              explicitly grant or deny consent. Read more at
#                              https://docs.kedro.org/en/stable/about/telemetry/

# %%
df = catalog.load("companies")
df.head()
# Out:
# [03/20/26 11:55:52] INFO     Loading data from companies (CSVDataset)...                       ]8;id=421845;file://C:\Users\pc\mi-proyecto-kedro\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=5094;file://C:\Users\pc\mi-proyecto-kedro\.venv\Lib\site-packages\kedro\io\data_catalog.py#1048\1048]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       id company_rating        company_location  total_fleet_count  \
# 0   3888           100%             Isle of Man                1.0
# 1  46728           100%                     NaN                1.0
# 2  34618            38%             Isle of Man                1.0
# 3  28619           100%  Bosnia and Herzegovina                1.0
# 4   8240            NaN                   Chile                1.0
#
#   iata_approved
# 0             f
# 1             f
# 2             f
# 3             f
# 4             t
