# %%
# %load_ext kedro.ipython
# Out:
# [03/20/26 14:10:41] INFO     Using                                                                  ]8;id=884033;file://C:\Users\pc\mi-proyecto-kedro\.venv\Lib\site-packages\kedro\framework\project\__init__.py\__init__.py]8;;\:]8;id=135978;file://C:\Users\pc\mi-proyecto-kedro\.venv\Lib\site-packages\kedro\framework\project\__init__.py#269\269]8;;\
#                              'C:\Users\pc\mi-proyecto-kedro\.venv\Lib\site-packages\kedro\framework
#                              \project\rich_logging.yml' as logging configuration.
# [03/20/26 14:10:42] INFO     Registered line magic '%reload_kedro'                                   ]8;id=201279;file://C:\Users\pc\mi-proyecto-kedro\.venv\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=972534;file://C:\Users\pc\mi-proyecto-kedro\.venv\Lib\site-packages\kedro\ipython\__init__.py#64\64]8;;\
# ...

# %%
catalog.keys()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     'companies',
#     'reviews',
#     'shuttles',
#     'preprocessed_companies',
#     'preprocessed_shuttles',
#     'model_input_table',
#     'regressor',
#     'shuttle_passenger_capacity_plot_exp',
#     'shuttle_passenger_capacity_plot_go',
#     'dummy_confusion_matrix',
#     'parameters',
#     'params:model_options',
#     'params:model_options.test_size',
#     'params:model_options.random_state',
#     'params:model_options.features'
# ]

# %%
companies = catalog.load("companies")
# Out:
# [03/20/26 14:12:26] INFO     Loading data from companies (CSVDataset)...                       ]8;id=200871;file://C:\Users\pc\mi-proyecto-kedro\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=744034;file://C:\Users\pc\mi-proyecto-kedro\.venv\Lib\site-packages\kedro\io\data_catalog.py#1048\1048]8;;\

# %%
companies['iata_approved'].describe()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# count     10017
# unique        2
# top           f
# freq       6001
# Name: iata_approved, dtype: object

# %%
def is_true(x):
    return x == "t"
x='f'
is_true(x)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# False

# %%
companies['iata_approved'].dtype
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# dtype('O')

# %%
companies
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#           id company_rating        company_location  total_fleet_count  \
# 0       3888           100%             Isle of Man                1.0
# 1      46728           100%                     NaN                1.0
# 2      34618            38%             Isle of Man                1.0
# 3      28619           100%  Bosnia and Herzegovina                1.0
# 4       8240            NaN                   Chile                1.0
# ...      ...            ...                     ...                ...
# 10014  20213            NaN      Russian Federation                1.0
# 10015   2235           100%                  Guinea                1.0
# 10016   2353           100%                 Senegal                2.0
# 10017  49772           100%                  Jersey                1.0
# ...

# %%
companies['iata_approved'].dtype
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# dtype('O')

# %%
is_true(companies['iata_approved'])
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 10014    False
# 10015    False
# 10016     True
# 10017    False
# 10018    False
# Name: iata_approved, Length: 10019, dtype: bool

# %%
import pandas as pd

# %%
def is_true(x: pd.Series) -> pd.Series:
    return x == "t"

# %%
x = 'f'
is_true(x)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# False

# %%
def parse_percentage(x: pd.Series) -> pd.Series:
    x = x.str.replace("%","")
    x = x.astype(float) / 100
    return x

# %%
parse_percentage(companies['company_rating'])
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 0        1.00
# 1        1.00
# 2        0.38
# 3        1.00
# 4         NaN
#          ...
# 10014     NaN
# 10015    1.00
# 10016    1.00
# 10017    1.00
# 10018    0.90
# Name: company_rating, Length: 10019, dtype: float64

# %%
def preprocess_companies(companies: pd.DataFrame) -> pd.DataFrame:
    """Preprocesses the data for companies.

    Args:
        companies: Raw data.
    Returns:
        Preprocessed data, with `company_rating` converted to a float and
        `iata_approved` converted to boolean.
    """
    companies["iata_approved"] = is_true(companies["iata_approved"])
    companies["company_rating"] = parse_percentage(companies["company_rating"])
    return companies

# %%
preprocess_companies(companies)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#           id  company_rating        company_location  total_fleet_count  \
# 0       3888            1.00             Isle of Man                1.0
# 1      46728            1.00                     NaN                1.0
# 2      34618            0.38             Isle of Man                1.0
# 3      28619            1.00  Bosnia and Herzegovina                1.0
# 4       8240             NaN                   Chile                1.0
# ...      ...             ...                     ...                ...
# 10014  20213             NaN      Russian Federation                1.0
# 10015   2235            1.00                  Guinea                1.0
# 10016   2353            1.00                 Senegal                2.0
# 10017  49772            1.00                  Jersey                1.0
# ...
